# %% [markdown]
# # 04 PyTorch MLP実験
#
# 同じ時系列分割でニューラルネットワークを学習します。

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.insert(0,str(ROOT))
from ml.train_neural_network import train

# %%
metrics=train()
metrics
