# %% [markdown]
# # 03 LightGBM実験
#
# 時系列順で分割し、基準モデルを学習します。

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.insert(0,str(ROOT))
from ml.train_lightgbm import train

# %%
metrics=train()
metrics
